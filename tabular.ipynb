# %% [markdown]
# <a href="https://colab.research.google.com/github/MUKESHRAJMAHENDRAN/Deep-Learning--fastai/blob/main/tabular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install fastai --upgrade

# %%
from fastai.tabular.all import *

# %%
df = pd.DataFrame({'date': ['2019-12-04', '2019-11-29', '2019-11-15', '2019-10-24']})

# %%
df
# Out:
#          date
# 0  2019-12-04
# 1  2019-11-29
# 2  2019-11-15
# 3  2019-10-24

# %%
type(df["date"])
# Out:
# pandas.core.series.Series

# %%
make_date(df, "date")

# %%
df.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df = pd.DataFrame({'date': ['2019-12-04', None, '2019-11-15', '2019-10-24']})

# %%
df
# Out:
#          date
# 0  2019-12-04
# 1        None
# 2  2019-11-15
# 3  2019-10-24

# %%
df.dtypes
# Out:
# date    object
# dtype: object

# %%
df = add_datepart(df, "date")

# %%
df
# Out:
#      Year  Month  Week   Day  Dayofweek  Dayofyear  Is_month_end  \
# 0  2019.0   12.0  49.0   4.0        2.0      338.0         False
# 1     NaN    NaN   NaN   NaN        NaN        NaN         False
# 2  2019.0   11.0  46.0  15.0        4.0      319.0         False
# 3  2019.0   10.0  43.0  24.0        3.0      297.0         False
#
#    Is_month_start  Is_quarter_end  Is_quarter_start  Is_year_end  \
# 0           False           False             False        False
# 1           False           False             False        False
# 2           False           False             False        False
# 3           False           False             False        False
#
#    Is_year_start       Elapsed
# 0          False  1.575418e+09
# 1          False           NaN
# 2          False  1.573776e+09
# 3          False  1.571875e+09

# %%
df = pd.DataFrame({'date': ['2019-12-04', '2019-11-29', '2019-11-15', '2019-10-24'],
                   'event': [False, True, False, True], 'base': [1,1,2,2]})

# %%
df
# Out:
#          date  event  base
# 0  2019-12-04  False     1
# 1  2019-11-29   True     1
# 2  2019-11-15  False     2
# 3  2019-10-24   True     2

# %%
df = add_elapsed_times(df, ['event'], 'date', 'base')
df.head()
# Out:
#         date  event  base  Afterevent  Beforeevent  event_bw  event_fw
# 0 2019-12-04  False     1           5            0       1.0       0.0
# 1 2019-11-29   True     1           0            0       1.0       1.0
# 2 2019-11-15  False     2          22            0       1.0       0.0
# 3 2019-10-24   True     2           0            0       1.0       1.0

# %%
df = pd.DataFrame({'cat1': [1, 2, 3, 4], 'cont1': [1., 2., 3., 2.], 'cat2': ['a', 'b', 'b', 'a'], 
                   'i8': pd.Series([1, 2, 3, 4], dtype='int8'), 
                   'u8': pd.Series([1, 2, 3, 4], dtype='uint8'), 
                   'f16': pd.Series([1, 2, 3, 4], dtype='float16'),
                   'y1': [1, 0, 1, 0], 'y2': [2, 1, 1, 0]})

# %%
df
# Out:
#    cat1  cont1 cat2  i8  u8  f16  y1  y2
# 0     1    1.0    a   1   1  1.0   1   2
# 1     2    2.0    b   2   2  2.0   0   1
# 2     3    3.0    b   3   3  3.0   1   1
# 3     4    2.0    a   4   4  4.0   0   0

# %%
df.dtypes
# Out:
# cat1       int64
# cont1    float64
# cat2      object
# i8          int8
# u8         uint8
# f16      float16
# y1         int64
# y2         int64
# dtype: object

# %%
cont_names, cat_names = cont_cat_split(df)

# %%
cont_names
# Out:
# ['cont1', 'f16']

# %%
cat_names
# Out:
# ['cat1', 'cat2', 'i8', 'u8', 'y1', 'y2']

# %%
df = pd.DataFrame({'cat1': pd.Series(['l','xs','xl','s'], dtype='category'),
                    'ui32': pd.Series([1, 2, 3, 4], dtype='UInt32'),
                    'i64': pd.Series([1, 2, 3, 4], dtype='Int64'),
                    'f16': pd.Series([1, 2, 3, 4], dtype='Float64'),
                    'd1_date': ['2021-02-09', None, '2020-05-12', '2020-08-14'],
                    })

# %%
df
# Out:
#   cat1  ui32  i64  f16     d1_date
# 0    l     1    1  1.0  2021-02-09
# 1   xs     2    2  2.0        None
# 2   xl     3    3  3.0  2020-05-12
# 3    s     4    4  4.0  2020-08-14

# %%
df = add_datepart(df, 'd1_date', drop=False)

# %%
df
# Out:
#   cat1  ui32  i64  f16    d1_date  d1_Year  d1_Month  d1_Week  d1_Day  \
# 0    l     1    1  1.0 2021-02-09   2021.0       2.0      6.0     9.0
# 1   xs     2    2  2.0        NaT      NaN       NaN      NaN     NaN
# 2   xl     3    3  3.0 2020-05-12   2020.0       5.0     20.0    12.0
# 3    s     4    4  4.0 2020-08-14   2020.0       8.0     33.0    14.0
#
#    d1_Dayofweek  d1_Dayofyear  d1_Is_month_end  d1_Is_month_start  \
# 0           1.0          40.0            False              False
# 1           NaN           NaN            False              False
# 2           1.0         133.0            False              False
# 3           4.0         227.0            False              False
#
#    d1_Is_quarter_end  d1_Is_quarter_start  d1_Is_year_end  d1_Is_year_start  \
# 0              False                False           False             False
# 1              False                False           False             False
# 2              False                False           False             False
# 3              False                False           False             False
#
#      d1_Elapsed
# 0  1.612829e+09
# 1           NaN
# 2  1.589242e+09
# 3  1.597363e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cat1                 4 non-null      category
#  1   ui32                 4 non-null      UInt32
#  2   i64                  4 non-null      Int64
#  3   f16                  4 non-null      Float64
#  4   d1_date              3 non-null      datetime64[ns]
#  5   d1_Year              3 non-null      float64
#  6   d1_Month             3 non-null      float64
#  7   d1_Week              3 non-null      float64
#  8   d1_Day               3 non-null      float64
#  9   d1_Dayofweek         3 non-null      float64
#  10  d1_Dayofyear         3 non-null      float64
#  11  d1_Is_month_end      4 non-null      bool
#  12  d1_Is_month_start    4 non-null      bool
#  13  d1_Is_quarter_end    4 non-null      bool
#  14  d1_Is_quarter_start  4 non-null      bool
#  15  d1_Is_year_end       4 non-null      bool
#  16  d1_Is_year_start     4 non-null      bool
#  17  d1_Elapsed           3 non-null      float64
# dtypes: Float64(1), Int64(1), UInt32(1), bool(6), category(1), datetime64[ns](1), float64(7)
# memory usage: 708.0 bytes

# %%
df['cat1'].cat.set_categories(['xl','l','m','s','xs'], ordered=True, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py:2631: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)

# %%
cont_names, cat_names = cont_cat_split(df, max_card=0)

# %%
cont_names
# Out:
# ['ui32',
#  'i64',
#  'f16',
#  'd1_Year',
#  'd1_Month',
#  'd1_Week',
#  'd1_Day',
#  'd1_Dayofweek',
#  'd1_Dayofyear',
#  'd1_Elapsed']

# %%
cat_names
# Out:
# ['cat1',
#  'd1_date',
#  'd1_Is_month_end',
#  'd1_Is_month_start',
#  'd1_Is_quarter_end',
#  'd1_Is_quarter_start',
#  'd1_Is_year_end',
#  'd1_Is_year_start']

# %%
df.cat1
# Out:
# 0     l
# 1    xs
# 2    xl
# 3     s
# Name: cat1, dtype: category
# Categories (5, object): ['xl' < 'l' < 'm' < 's' < 'xs']

# %%
df = pd.DataFrame({'i': [-100, 0, 100], 'f': [-100.0, 0.0, 100.0], 'e': [True, False, True],
                   'date':['2019-12-04','2019-11-29','2019-11-15',]})
df.dtypes
# Out:
# i         int64
# f       float64
# e          bool
# date     object
# dtype: object

# %%
dt = df_shrink_dtypes(df)
dt
# Out:
# {'date': 'category', 'f': dtype('float32'), 'i': dtype('int8')}

# %%
df = pd.DataFrame({'i': [-100, 0, 100], 'f': [-100.0, 0.0, 100.0], 'u':[0, 10,254],
                  'date':['2019-12-04','2019-11-29','2019-11-15']})
#df2 = df_shrink(df, skip=['date'])

# %%
df2 = df_shrink(df)

# %%
df2
# Out:
#      i      f    u        date
# 0 -100 -100.0    0  2019-12-04
# 1    0    0.0   10  2019-11-29
# 2  100  100.0  254  2019-11-15

# %%
df3 = df_shrink(df, skip=['date'])
df3
# Out:
#      i      f    u        date
# 0 -100 -100.0    0  2019-12-04
# 1    0    0.0   10  2019-11-29
# 2  100  100.0  254  2019-11-15

# %%
df.dtypes
# Out:
# i         int64
# f       float64
# u         int64
# date     object
# dtype: object

# %%
df2.dtypes
# Out:
# i           int8
# f        float32
# u          int16
# date    category
# dtype: object

# %%
df3.dtypes
# Out:
# i          int8
# f       float32
# u         int16
# date     object
# dtype: object

# %%
df = pd.DataFrame({'a':[0,1,2,0,2]})
to = TabularPandas(df, Categorify, 'a')
to.show()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>

# %%
cat = to.procs.categorify
cat.classes
# Out:
# {'a': ['#na#', 0, 1, 2]}

# %%
path = untar_data(URLs.ADULT_SAMPLE)
df = pd.read_csv(path/'adult.csv')
df_main,df_test = df.iloc[:10000].copy(),df.iloc[10000:].copy()
df_test.drop('salary', axis=1, inplace=True)
df_main.head()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='974848' class='' max='968212' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.69% [974848/968212 00:00<00:00]
#     </div>
#    age          workclass  fnlwgt     education  education-num  \
# 0   49            Private  101320    Assoc-acdm           12.0
# 1   44            Private  236746       Masters           14.0
# 2   38            Private   96185       HS-grad            NaN
# 3   38       Self-emp-inc  112847   Prof-school           15.0
# 4   42   Self-emp-not-inc   82297       7th-8th            NaN
#
#         marital-status        occupation    relationship                 race  \
# 0   Married-civ-spouse               NaN            Wife                White
# 1             Divorced   Exec-managerial   Not-in-family                White
# 2             Divorced               NaN       Unmarried                Black
# 3   Married-civ-spouse    Prof-specialty         Husband   Asian-Pac-Islander
# 4   Married-civ-spouse     Other-service            Wife                Black
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country salary
# 0   Female             0          1902              40   United-States  >=50k
# 1     Male         10520             0              45   United-States  >=50k
# 2   Female             0             0              32   United-States   <50k
# 3     Male             0             0              40   United-States  >=50k
# 4   Female             0             0              50   United-States   <50k

# %%
cat_names = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race']
cont_names = ['age', 'fnlwgt', 'education-num']
procs = [Categorify, FillMissing, Normalize]
splits = RandomSplitter()(range_of(df_main))

# %%
to = TabularPandas(df_main, procs, cat_names, cont_names, y_names="salary", splits=splits)

# %%
dls = to.dataloaders()
dls.valid.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>workclass</th>
#       <th>education</th>
#       <th>marital-status</th>
#       <th>occupation</th>
#       <th>relationship</th>
#       <th>race</th>
#       <th>education-num_na</th>
#       <th>age</th>
#       <th>fnlwgt</th>
#       <th>education-num</th>
#       <th>salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>?</td>
#       <td>Bachelors</td>
#       <td>Divorced</td>
#       <td>?</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>44.000000</td>
#       <td>248875.998939</td>
#       <td>13.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Federal-gov</td>
#       <td>Some-college</td>
#       <td>Divorced</td>
#       <td>Protective-serv</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>34.000000</td>
#       <td>223266.999114</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Private</td>
#       <td>Masters</td>
#       <td>Married-civ-spouse</td>
#       <td>Exec-managerial</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>37.000000</td>
#       <td>174150.000059</td>
#       <td>14.0</td>
#       <td>&gt;=50k</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Prof-specialty</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>20.000001</td>
#       <td>138938.000712</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Handlers-cleaners</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>23.999999</td>
#       <td>165063.998512</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Divorced</td>
#       <td>Exec-managerial</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>28.000000</td>
#       <td>250134.998727</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Private</td>
#       <td>5th-6th</td>
#       <td>Married-civ-spouse</td>
#       <td>Farming-fishing</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>27.000000</td>
#       <td>279608.002655</td>
#       <td>3.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Divorced</td>
#       <td>Adm-clerical</td>
#       <td>Unmarried</td>
#       <td>White</td>
#       <td>False</td>
#       <td>33.000000</td>
#       <td>104509.000082</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Private</td>
#       <td>12th</td>
#       <td>Divorced</td>
#       <td>Machine-op-inspct</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>28.000000</td>
#       <td>184077.999973</td>
#       <td>8.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Married-civ-spouse</td>
#       <td>Craft-repair</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>45.000000</td>
#       <td>330087.000544</td>
#       <td>9.0</td>
#       <td>&lt;50k</td>
#     </tr>
#   </tbody>
# </table>

# %%
to.show()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>workclass</th>
#       <th>education</th>
#       <th>marital-status</th>
#       <th>occupation</th>
#       <th>relationship</th>
#       <th>race</th>
#       <th>education-num_na</th>
#       <th>age</th>
#       <th>fnlwgt</th>
#       <th>education-num</th>
#       <th>salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7063</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Adm-clerical</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>18.0</td>
#       <td>400616.0</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>7141</th>
#       <td>Self-emp-not-inc</td>
#       <td>HS-grad</td>
#       <td>Divorced</td>
#       <td>Farming-fishing</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>34.0</td>
#       <td>80933.0</td>
#       <td>9.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>1006</th>
#       <td>Self-emp-not-inc</td>
#       <td>Assoc-acdm</td>
#       <td>Married-civ-spouse</td>
#       <td>Sales</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>29.0</td>
#       <td>179008.0</td>
#       <td>12.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>2287</th>
#       <td>Local-gov</td>
#       <td>Assoc-voc</td>
#       <td>Never-married</td>
#       <td>Adm-clerical</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>37.0</td>
#       <td>144322.0</td>
#       <td>11.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>3373</th>
#       <td>Local-gov</td>
#       <td>Bachelors</td>
#       <td>Married-civ-spouse</td>
#       <td>Prof-specialty</td>
#       <td>Wife</td>
#       <td>White</td>
#       <td>False</td>
#       <td>53.0</td>
#       <td>248834.0</td>
#       <td>13.0</td>
#       <td>&gt;=50k</td>
#     </tr>
#     <tr>
#       <th>8480</th>
#       <td>Self-emp-not-inc</td>
#       <td>11th</td>
#       <td>Divorced</td>
#       <td>Exec-managerial</td>
#       <td>Unmarried</td>
#       <td>White</td>
#       <td>False</td>
#       <td>35.0</td>
#       <td>264627.0</td>
#       <td>7.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>1254</th>
#       <td>Private</td>
#       <td>Bachelors</td>
#       <td>Never-married</td>
#       <td>Adm-clerical</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>27.0</td>
#       <td>176514.0</td>
#       <td>13.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>7813</th>
#       <td>Private</td>
#       <td>Doctorate</td>
#       <td>Married-civ-spouse</td>
#       <td>Prof-specialty</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>55.0</td>
#       <td>116878.0</td>
#       <td>16.0</td>
#       <td>&gt;=50k</td>
#     </tr>
#     <tr>
#       <th>4377</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Never-married</td>
#       <td>Machine-op-inspct</td>
#       <td>Not-in-family</td>
#       <td>Black</td>
#       <td>False</td>
#       <td>37.0</td>
#       <td>188377.0</td>
#       <td>9.0</td>
#       <td>&lt;50k</td>
#     </tr>
#     <tr>
#       <th>8053</th>
#       <td>Self-emp-inc</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Other-service</td>
#       <td>Own-child</td>
#       <td>Asian-Pac-Islander</td>
#       <td>False</td>
#       <td>19.0</td>
#       <td>148955.0</td>
#       <td>10.0</td>
#       <td>&lt;50k</td>
#     </tr>
#   </tbody>
# </table>

# %%
row = to.items.iloc[0]
to.decode_row(row)
# Out:
# age                           18.0
# workclass                  Private
# fnlwgt                    400616.0
# education             Some-college
# education-num                 10.0
# marital-status       Never-married
# occupation            Adm-clerical
# relationship             Own-child
# race                         White
# sex                           Male
# capital-gain                     0
# capital-loss                     0
# hours-per-week                  40
# native-country       United-States
# salary                        <50k
# education-num_na             False
# Name: 7063, dtype: object

# %%
to_tst = to.new(df_test)
to_tst.process()
to_tst.items.head()
# Out:
#             age  workclass    fnlwgt  education  education-num  \
# 10000  0.459920          5  1.329529         10       1.180124
# 10001 -0.936031          5  1.243048         12      -0.419570
# 10002  1.047689          5  0.147246          2      -1.219417
# 10003  0.533391          5 -0.283158         12      -0.419570
# 10004  0.753805          6  1.431423          9       0.380277
#
#        marital-status  occupation  relationship  race      sex  capital-gain  \
# 10000               3           2             1     2     Male             0
# 10001               3          15             1     4     Male             0
# 10002               1           9             2     5   Female             0
# 10003               7           2             5     5   Female             0
# 10004               3           5             1     5     Male             0
#
#        capital-loss  hours-per-week  native-country  education-num_na
# 10000             0              40     Philippines                 1
# 10001             0              40   United-States                 1
# 10002             0              37   United-States                 1
# 10003             0              43   United-States                 1
# 10004             0              60   United-States                 1

# %%
tst_dl = dls.valid.new(to_tst)
tst_dl.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>workclass</th>
#       <th>education</th>
#       <th>marital-status</th>
#       <th>occupation</th>
#       <th>relationship</th>
#       <th>race</th>
#       <th>education-num_na</th>
#       <th>age</th>
#       <th>fnlwgt</th>
#       <th>education-num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Private</td>
#       <td>Bachelors</td>
#       <td>Married-civ-spouse</td>
#       <td>Adm-clerical</td>
#       <td>Husband</td>
#       <td>Asian-Pac-Islander</td>
#       <td>False</td>
#       <td>45.000000</td>
#       <td>338104.998511</td>
#       <td>13.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Married-civ-spouse</td>
#       <td>Transport-moving</td>
#       <td>Husband</td>
#       <td>Other</td>
#       <td>False</td>
#       <td>26.000000</td>
#       <td>328662.997941</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Private</td>
#       <td>11th</td>
#       <td>Divorced</td>
#       <td>Other-service</td>
#       <td>Not-in-family</td>
#       <td>White</td>
#       <td>False</td>
#       <td>53.000001</td>
#       <td>209021.999570</td>
#       <td>7.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Private</td>
#       <td>HS-grad</td>
#       <td>Widowed</td>
#       <td>Adm-clerical</td>
#       <td>Unmarried</td>
#       <td>White</td>
#       <td>False</td>
#       <td>46.000000</td>
#       <td>162029.999894</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Self-emp-inc</td>
#       <td>Assoc-voc</td>
#       <td>Married-civ-spouse</td>
#       <td>Exec-managerial</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>49.000000</td>
#       <td>349229.995258</td>
#       <td>11.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Local-gov</td>
#       <td>Some-college</td>
#       <td>Married-civ-spouse</td>
#       <td>Exec-managerial</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>34.000000</td>
#       <td>124826.999658</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Self-emp-inc</td>
#       <td>Some-college</td>
#       <td>Married-civ-spouse</td>
#       <td>Sales</td>
#       <td>Husband</td>
#       <td>White</td>
#       <td>False</td>
#       <td>53.000001</td>
#       <td>290639.997815</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Sales</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>19.000000</td>
#       <td>106272.997640</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Married-civ-spouse</td>
#       <td>Protective-serv</td>
#       <td>Husband</td>
#       <td>Black</td>
#       <td>False</td>
#       <td>72.000001</td>
#       <td>53683.994120</td>
#       <td>10.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Private</td>
#       <td>Some-college</td>
#       <td>Never-married</td>
#       <td>Sales</td>
#       <td>Own-child</td>
#       <td>White</td>
#       <td>False</td>
#       <td>20.000001</td>
#       <td>505980.001479</td>
#       <td>10.0</td>
#     </tr>
#   </tbody>
# </table>
